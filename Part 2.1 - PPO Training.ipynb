# %% [markdown]
# # `Stable-Baselines3` Tutorial - Part 2 (PPO)
# **Contents:**
# - Saving
# - Loading
# - Tracking performance
#
# Created by following [this](https://pythonprogramming.net/introduction-reinforcement-learning-stable-baselines-3-tutorial/) tutorial by sentdex.
# <br> <br> **Note:** This does not need to be a jupyter notebook and could just as well by a `.py` file

# %%
import gym
from stable_baselines3 import PPO 
import os

# %%
env = gym.make('LunarLander-v2')

# %%
# Create necessary directories
models_dir = 'models/PPO'
log_dir = 'logs'

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
# Train model - save and log along the way
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_dir)

TIMESTEPS = 10_000 # number of timesteps between saves
for i in range(1,30):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name='PPO')
    model.save(f'{models_dir}/{TIMESTEPS*i}')
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.4     |
# |    ep_rew_mean     | -188     |
# | time/              |          |
# |    fps             | 275      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.7        |
# |    ep_rew_mean          | -175        |
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010208233 |
# |    clip_fraction        | 0.0305      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00144     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 539         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00663    |
# |    value_loss           | 1.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.8        |
# |    ep_rew_mean          | -170        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010264582 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0401     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 436         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00918    |
# |    value_loss           | 955         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.7        |
# |    ep_rew_mean          | -171        |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 4           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012898788 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.00865    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 366         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 814         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -171        |
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 5           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009985087 |
# |    clip_fraction        | 0.0588      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.000802   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 345         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00937    |
# |    value_loss           | 756         |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | -167     |
# | time/              |          |
# |    fps             | 461      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 12288    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | -162        |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008189308 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00685    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 208         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 622         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | -159        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011126671 |
# |    clip_fraction        | 0.0991      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.000831   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 142         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00603    |
# |    value_loss           | 398         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | -160        |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 4           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008572333 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | -0.000158   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 227         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00701    |
# |    value_loss           | 382         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 128          |
# |    ep_rew_mean          | -150         |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 5            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0073694484 |
# |    clip_fraction        | 0.0372       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -0.00633     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 172          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00635     |
# |    value_loss           | 570          |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | -137     |
# | time/              |          |
# |    fps             | 397      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 22528    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | -124        |
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005366766 |
# |    clip_fraction        | 0.0965      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -4.49e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 193         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00875    |
# |    value_loss           | 386         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 312         |
# |    iterations           | 3           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015397444 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 6.2e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00732    |
# |    value_loss           | 175         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 162         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 4           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009335326 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.00026     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 360         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00779    |
# |    value_loss           | 412         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 5           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010869443 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -0.00872    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00529    |
# |    value_loss           | 169         |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 186      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    fps             | 375      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 32768    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.006287027 |
# |    clip_fraction        | 0.0233      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | -0.0833     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 168         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00582    |
# |    value_loss           | 253         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | -99.9        |
# | time/                   |              |
# |    fps                  | 306          |
# |    iterations           | 3            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0071961875 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.122        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 242          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00805     |
# |    value_loss           | 315          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 210          |
# |    ep_rew_mean          | -96.1        |
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 4            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0031133634 |
# |    clip_fraction        | 0.00967      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.0484       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 167          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00503     |
# |    value_loss           | 274          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 223         |
# |    ep_rew_mean          | -86.9       |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 5           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006314163 |
# |    clip_fraction        | 0.021       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 111         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 335         |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 235      |
# |    ep_rew_mean     | -85.1    |
# | time/              |          |
# |    fps             | 339      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 43008    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 253         |
# |    ep_rew_mean          | -82.5       |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007776996 |
# |    clip_fraction        | 0.0538      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.52        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 85.5        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00587    |
# |    value_loss           | 139         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 267          |
# |    ep_rew_mean          | -82.8        |
# | time/                   |              |
# |    fps                  | 265          |
# |    iterations           | 3            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0058355383 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.384        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.5         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00561     |
# |    value_loss           | 131          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 281         |
# |    ep_rew_mean          | -83.3       |
# | time/                   |             |
# |    fps                  | 267         |
# |    iterations           | 4           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012348249 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.5        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00774    |
# |    value_loss           | 92.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 299         |
# |    ep_rew_mean          | -83.1       |
# | time/                   |             |
# |    fps                  | 266         |
# |    iterations           | 5           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008983956 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.984      |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.2        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00737    |
# |    value_loss           | 163         |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 313      |
# |    ep_rew_mean     | -81.9    |
# | time/              |          |
# |    fps             | 319      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 53248    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 332         |
# |    ep_rew_mean          | -77.1       |
# | time/                   |             |
# |    fps                  | 264         |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008423768 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.5        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00901    |
# |    value_loss           | 111         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | -72.1        |
# | time/                   |              |
# |    fps                  | 247          |
# |    iterations           | 3            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0065559987 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.821        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.8         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00594     |
# |    value_loss           | 58           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -69.8       |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 4           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.013165712 |
# |    clip_fraction        | 0.0739      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.6        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00837    |
# |    value_loss           | 44.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 376         |
# |    ep_rew_mean          | -68.1       |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 5           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.017485999 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.881      |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00551    |
# |    value_loss           | 70.9        |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 394      |
# |    ep_rew_mean     | -68.6    |
# | time/              |          |
# |    fps             | 307      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 63488    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 419         |
# |    ep_rew_mean          | -64.6       |
# | time/                   |             |
# |    fps                  | 265         |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004563197 |
# |    clip_fraction        | 0.0376      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.857      |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.9        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 46.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 432         |
# |    ep_rew_mean          | -58.7       |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011649478 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.878      |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.8        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00864    |
# |    value_loss           | 32.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 451          |
# |    ep_rew_mean          | -51.5        |
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 4            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0042756633 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.927       |
# |    explained_variance   | 0.191        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.8         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00354     |
# |    value_loss           | 152          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | -42.9       |
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 5           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.003699513 |
# |    clip_fraction        | 0.0122      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.833      |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0029     |
# |    value_loss           | 105         |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 474      |
# |    ep_rew_mean     | -35.1    |
# | time/              |          |
# |    fps             | 305      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 73728    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 476         |
# |    ep_rew_mean          | -33.5       |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008515311 |
# |    clip_fraction        | 0.0983      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 77.8        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00393    |
# |    value_loss           | 172         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 492          |
# |    ep_rew_mean          | -21.7        |
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 3            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0050945817 |
# |    clip_fraction        | 0.0664       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.958       |
# |    explained_variance   | 0.466        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.7         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00511     |
# |    value_loss           | 149          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 499         |
# |    ep_rew_mean          | -18.7       |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 4           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.003975548 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.764      |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.2        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00289    |
# |    value_loss           | 125         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 515          |
# |    ep_rew_mean          | -1.55        |
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 5            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0022063572 |
# |    clip_fraction        | 0.00679      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.867       |
# |    explained_variance   | 0.22         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 81.7         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00245     |
# |    value_loss           | 168          |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 515      |
# |    ep_rew_mean     | 7.75     |
# | time/              |          |
# |    fps             | 334      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 83968    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 523        |
# |    ep_rew_mean          | 13.7       |
# | time/                   |            |
# |    fps                  | 281        |
# |    iterations           | 2          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.00972984 |
# |    clip_fraction        | 0.0385     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.815     |
# |    explained_variance   | 0.498      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 37.6       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00575   |
# |    value_loss           | 109        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 537          |
# |    ep_rew_mean          | 18.6         |
# | time/                   |              |
# |    fps                  | 277          |
# |    iterations           | 3            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0060887085 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.8         |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.1         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00597     |
# |    value_loss           | 214          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 549          |
# |    ep_rew_mean          | 24.7         |
# | time/                   |              |
# |    fps                  | 271          |
# |    iterations           | 4            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0068386397 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.819       |
# |    explained_variance   | 0.331        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 95.9         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 247          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 562        |
# |    ep_rew_mean          | 30.4       |
# | time/                   |            |
# |    fps                  | 264        |
# |    iterations           | 5          |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00748568 |
# |    clip_fraction        | 0.0683     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.839     |
# |    explained_variance   | 0.355      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 96.6       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00541   |
# |    value_loss           | 152        |
# ----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 575      |
# |    ep_rew_mean     | 34.6     |
# | time/              |          |
# |    fps             | 353      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 94208    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 580          |
# |    ep_rew_mean          | 42.8         |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0031037899 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.893       |
# |    explained_variance   | 0.476        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 94.3         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 126          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 586         |
# |    ep_rew_mean          | 52.5        |
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.004280329 |
# |    clip_fraction        | 0.0183      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.872      |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.8        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00121    |
# |    value_loss           | 101         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 600          |
# |    ep_rew_mean          | 59.8         |
# | time/                   |              |
# |    fps                  | 274          |
# |    iterations           | 4            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0024735264 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.875       |
# |    explained_variance   | 0.384        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 142          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 176          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 612          |
# |    ep_rew_mean          | 61.1         |
# | time/                   |              |
# |    fps                  | 271          |
# |    iterations           | 5            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0029311606 |
# |    clip_fraction        | 0.0742       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.892       |
# |    explained_variance   | 0.45         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.1         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 124          |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 605      |
# |    ep_rew_mean     | 65.3     |
# | time/              |          |
# |    fps             | 367      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 104448   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 607          |
# |    ep_rew_mean          | 70.1         |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0073133605 |
# |    clip_fraction        | 0.0756       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.884       |
# |    explained_variance   | 0.565        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 186          |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00356     |
# |    value_loss           | 129          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 607         |
# |    ep_rew_mean          | 80.4        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.004754847 |
# |    clip_fraction        | 0.0324      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.7        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0028     |
# |    value_loss           | 132         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 612          |
# |    ep_rew_mean          | 90.3         |
# | time/                   |              |
# |    fps                  | 279          |
# |    iterations           | 4            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0062231785 |
# |    clip_fraction        | 0.0565       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.945       |
# |    explained_variance   | 0.433        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.1         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 105          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 609          |
# |    ep_rew_mean          | 98.2         |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 5            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0066339946 |
# |    clip_fraction        | 0.0567       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.836       |
# |    explained_variance   | 0.488        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 217          |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00324     |
# |    value_loss           | 176          |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 604      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    fps             | 363      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 114688   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 600          |
# |    ep_rew_mean          | 105          |
# | time/                   |              |
# |    fps                  | 305          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0047329366 |
# |    clip_fraction        | 0.0506       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.883       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.7         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00169     |
# |    value_loss           | 55.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 597         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 278         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.007407725 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.972      |
# |    explained_variance   | 0.547       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.3        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 102         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 580          |
# |    ep_rew_mean          | 118          |
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 4            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0050739697 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.866       |
# |    explained_variance   | 0.412        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23           |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00428     |
# |    value_loss           | 119          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 580          |
# |    ep_rew_mean          | 116          |
# | time/                   |              |
# |    fps                  | 266          |
# |    iterations           | 5            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0057913843 |
# |    clip_fraction        | 0.0724       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.894       |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.1         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 59.6         |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 577      |
# |    ep_rew_mean     | 121      |
# | time/              |          |
# |    fps             | 327      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 124928   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 567          |
# |    ep_rew_mean          | 122          |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0067227436 |
# ...
# |    learning_rate        | 0.0003       |
# |    loss                 | 104          |
# |    n_updates            | 1240         |
# |    policy_gradient_loss | -0.00453     |
# |    value_loss           | 174          |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 355      |
# |    ep_rew_mean     | 222      |
# | time/              |          |
# |    fps             | 353      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 258048   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 360          |
# |    ep_rew_mean          | 218          |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 260096       |
# | train/                  |              |
# |    approx_kl            | 0.0063584214 |
# |    clip_fraction        | 0.0916       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.694       |
# |    explained_variance   | 0.371        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.8         |
# |    n_updates            | 1260         |
# |    policy_gradient_loss | -0.000776    |
# |    value_loss           | 150          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 358         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.012003956 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.742      |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.6        |
# |    n_updates            | 1270        |
# |    policy_gradient_loss | -0.00449    |
# |    value_loss           | 134         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 357          |
# |    ep_rew_mean          | 220          |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 4            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 264192       |
# | train/                  |              |
# |    approx_kl            | 0.0055268533 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | 0.635        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.8         |
# |    n_updates            | 1280         |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 50           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 352          |
# |    ep_rew_mean          | 219          |
# | time/                   |              |
# |    fps                  | 289          |
# |    iterations           | 5            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 266240       |
# | train/                  |              |
# |    approx_kl            | 0.0068771653 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.725       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.4         |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 62.6         |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 351      |
# |    ep_rew_mean     | 223      |
# | time/              |          |
# |    fps             | 384      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 268288   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 349         |
# |    ep_rew_mean          | 222         |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.006049875 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.92        |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.00258    |
# |    value_loss           | 18.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | 220          |
# | time/                   |              |
# |    fps                  | 318          |
# |    iterations           | 3            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 272384       |
# | train/                  |              |
# |    approx_kl            | 0.0060575297 |
# |    clip_fraction        | 0.0533       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.717       |
# |    explained_variance   | 0.727        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 116          |
# |    n_updates            | 1320         |
# |    policy_gradient_loss | -0.00321     |
# |    value_loss           | 99           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | 222          |
# | time/                   |              |
# |    fps                  | 310          |
# |    iterations           | 4            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 274432       |
# | train/                  |              |
# |    approx_kl            | 0.0056869406 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.714       |
# |    explained_variance   | 0.732        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.8         |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | -0.00323     |
# |    value_loss           | 122          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 346          |
# |    ep_rew_mean          | 218          |
# | time/                   |              |
# |    fps                  | 305          |
# |    iterations           | 5            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0042306148 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.674       |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.03         |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.00286     |
# |    value_loss           | 10.3         |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 351      |
# |    ep_rew_mean     | 216      |
# | time/              |          |
# |    fps             | 384      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 278528   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 341         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 280576      |
# | train/                  |             |
# |    approx_kl            | 0.004858418 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.741      |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99.7        |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.000842   |
# |    value_loss           | 143         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 346          |
# |    ep_rew_mean          | 218          |
# | time/                   |              |
# |    fps                  | 309          |
# |    iterations           | 3            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 282624       |
# | train/                  |              |
# |    approx_kl            | 0.0055865003 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.697       |
# |    explained_variance   | 0.818        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.7         |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 53           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 344         |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 4           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.005312649 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.708      |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.9         |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.00283    |
# |    value_loss           | 26.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 336        |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 301        |
# |    iterations           | 5          |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 286720     |
# | train/                  |            |
# |    approx_kl            | 0.00264275 |
# |    clip_fraction        | 0.0201     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.729     |
# |    explained_variance   | 0.775      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 60.5       |
# |    n_updates            | 1390       |
# |    policy_gradient_loss | -0.00354   |
# |    value_loss           | 113        |
# ----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 344      |
# |    ep_rew_mean     | 214      |
# | time/              |          |
# |    fps             | 356      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 288768   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 336          |
# |    ep_rew_mean          | 213          |
# | time/                   |              |
# |    fps                  | 312          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 290816       |
# | train/                  |              |
# |    approx_kl            | 0.0034096267 |
# |    clip_fraction        | 0.0505       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.706       |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.42         |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 40.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 330         |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.002734591 |
# |    clip_fraction        | 0.0228      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.705      |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.4        |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 165         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 336          |
# |    ep_rew_mean          | 210          |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 4            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0051065716 |
# |    clip_fraction        | 0.0619       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.695       |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.7         |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | -0.00506     |
# |    value_loss           | 162          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 5           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.012680346 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.718      |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.9        |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | -0.00517    |
# |    value_loss           | 76.4        |
# -----------------------------------------

# %% [markdown]
# ### To access tensorboard:
# 1. Open conda powershell
# 2. Switch to the right environment e.g `conda activate rl_env`
# 3. Navigate to the root directory of the `logs` folder with `cd` and `ls`
# 4. Run `tensorboard --logdir=logs`
# 5. Take the link and paste into any browser e.g `http://localhost:6006/`
